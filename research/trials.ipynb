# %%
from box import ConfigBox

# %%
d = {"key": "value", "key1": "value1"}

# %%
d['key']
# Out:
# 'value'

# %%
d2 = ConfigBox({"key": "value", "key1": "value1"})

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key
# Out:
# 'value'

# %%
def get_product(x: int, y:int) -> int:
  return x*y

# %%
get_product(x=2, y=4)
# Out:
# 8

# %%
get_product(x = 2, y = "4")
# Out:
# '44'

# %%
import unittest
unittest.TestCase.assertRaisesRegexp = unittest.TestCase.assertRaisesRegex

from ensure import ensure_annotations
# Out:
# Finally! ensure_annotations is imported.

# %%
@ensure_annotations
def get_product(x: int, y: int) -> int:
    return x * y

# %%
get_product(x = 2, y = 4)
# Out:
# 8

# %%
get_product(x = 2, y = "4")
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\suhas\anaconda3\envs\text\Lib\site-packages\IPython\core\interactiveshell.py", line 3701, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\suhas\AppData\Local\Temp\ipykernel_1088\325761201.py", line 1, in <module>
#     get_product(x = 2, y = "4")
#   File "c:\Users\suhas\anaconda3\envs\text\Lib\site-packages\ensure\main.py", line 845, in __call__
#     raise EnsureError(msg.format(
# ensure.main.EnsureError: Argument y of type <class 'str'> to <function get_product at 0x00000246A5504CC0> does not match annotation type <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\suhas\anaconda3\envs\text\Lib\site-packages\IPython\core\interactiveshell.py", line 2201, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\suhas\anaconda3\envs\text\Lib\site-packages\IPython\core\ultratb.py", line 1193, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\suhas\anaconda3\envs\text\Lib\site-packages\IPython\core\ultratb.py", line 1064, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\suhas\anaconda3\envs\text\Lib\site-packages\IPython\core\ultratb.py", line 872, in structured_traceback
#     formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#                                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\suhas\anaconda3\envs\text\Lib\site-packages\IPython\core\ultratb.py", line 784, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\suhas\anaconda3\envs\text\Lib\site-packages\IPython\core\ultratb.py", line 660, in format_record
#     frame_info.lines,
#     ^^^^^^^^^^^^^^^^
#   File "c:\Users\suhas\anaconda3\envs\text\Lib\site-packages\IPython\core\tbtools.py", line 356, in lines
#     return self._sd.lines  # type: ignore[misc]
#            ^^^^^^^^^^^^^^
#   File "c:\Users\suhas\anaconda3\envs\text\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "c:\Users\suhas\anaconda3\envs\text\Lib\site-packages\stack_data\core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\suhas\anaconda3\envs\text\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "c:\Users\suhas\anaconda3\envs\text\Lib\site-packages\stack_data\core.py", line 677, in included_pieces
#     scope_pieces = self.scope_pieces
#                    ^^^^^^^^^^^^^^^^^
#   File "c:\Users\suhas\anaconda3\envs\text\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "c:\Users\suhas\anaconda3\envs\text\Lib\site-packages\stack_data\core.py", line 614, in scope_pieces
#     scope_start, scope_end = self.source.line_range(self.scope)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\suhas\anaconda3\envs\text\Lib\site-packages\stack_data\core.py", line 178, in line_range
#     return line_range(self.asttext(), node)
#                       ^^^^^^^^^^^^
# AttributeError: 'Source' object has no attribute 'asttext'
